# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
import json
import pandas as pd
from sklearn.model_selection import train_test_split


import torch
from torch.utils.data import Dataset
from PIL import Image

from transformers import AutoFeatureExtractor, AutoTokenizer, VisionEncoderDecoderModel
from transformers import TrOCRProcessor
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import default_data_collator
# Out:
# 2024-03-22 10:29:21.121230: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-22 10:29:21.627121: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-22 10:29:21.627169: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-22 10:29:21.627174: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from evaluate import load

wer_metric = load("wer")

# %%
encoder = "microsoft/swin-tiny-patch4-window7-224"
decoder = "sentence-transformers/all-MiniLM-L6-v2"

# %%
data = json.load(open('annotations/captions_train2014.json'))

# %%
len(data['annotations'])
# Out:
# 414113

# %%
id2filename = {i['id']:i['file_name'] for i in data['images']}

# %%
df = pd.DataFrame(data['annotations'])

# %%
df['file_name'] = df['image_id'].map(id2filename)

# %%
df
# Out:
#         image_id      id                                            caption  \
# 0         318556      48     A very clean and well decorated empty bathroom
# 1         116100      67  A panoramic view of a kitchen and all of its a...
# 2         318556     126  A blue and white bathroom with butterfly theme...
# 3         116100     148     A panoramic photo of a kitchen and dining room
# 4         379340     173  A graffiti-ed stop sign across the street from...
# ...          ...     ...                                                ...
# 414108    133071  829655  a slice of bread is covered with a sour cream ...
# 414109    410182  829658  A long plate hold some fries with some sliders...
# 414110    180285  829665       Two women sit and pose with stuffed animals.
# 414111    133071  829693  White Plate with a lot of guacamole and an ext...
# 414112    133071  829717      A dinner plate has a lemon wedge garnishment.
#
#                               file_name
# 0       COCO_train2014_000000318556.jpg
# 1       COCO_train2014_000000116100.jpg
# 2       COCO_train2014_000000318556.jpg
# 3       COCO_train2014_000000116100.jpg
# 4       COCO_train2014_000000379340.jpg
# ...                                 ...
# 414108  COCO_train2014_000000133071.jpg
# 414109  COCO_train2014_000000410182.jpg
# 414110  COCO_train2014_000000180285.jpg
# 414111  COCO_train2014_000000133071.jpg
# 414112  COCO_train2014_000000133071.jpg
#
# [414113 rows x 4 columns]

# %%
train_df, test_df = train_test_split(df, test_size=0.1)
train_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
class ImageCaptioningDataset(Dataset):
    def __init__(self, root_dir, df, processor, max_target_length=128):
        self.root_dir = root_dir
        self.df = df
        self.processor = processor
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # get file name + text 
        file_name = self.df['file_name'][idx]
        text = self.df['caption'][idx]
        # prepare image (i.e. resize + normalize)
        image = Image.open(self.root_dir + file_name).convert("RGB")
        pixel_values = self.processor(image, return_tensors="pt").pixel_values
        # add labels (input_ids) by encoding the text
        labels = self.processor.tokenizer(text, 
                                          padding="max_length", 
                                          max_length=self.max_target_length).input_ids
        # important: make sure that PAD tokens are ignored by the loss function
        labels = [label if label != self.processor.tokenizer.pad_token_id else -100 for label in labels]

        encoding = {"pixel_values": pixel_values.squeeze(), "labels": torch.tensor(labels)}
        return encoding

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained(encoder)
tokenizer = AutoTokenizer.from_pretrained(decoder)

processor = TrOCRProcessor(feature_extractor, tokenizer)
# Out:
# /home/vladimir/.virtualenvs/ml/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
train_dataset = ImageCaptioningDataset(root_dir='train2014/',
                           df=train_df,
                           processor=processor)
eval_dataset = ImageCaptioningDataset(root_dir='train2014/',
                           df=test_df,
                           processor=processor)

# %%
encoding = train_dataset[0]
for k,v in encoding.items():
    print(k, v.shape)
# Out:
# pixel_values torch.Size([3, 224, 224])
# labels torch.Size([128])

# %%
image = Image.open(train_dataset.root_dir + train_df['file_name'][0]).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>

# %%
labels = encoding['labels']
labels[labels == -100] = processor.tokenizer.pad_token_id
label_str = processor.decode(labels, skip_special_tokens=True)
print(label_str)
# Out:
# a bathroom with a sink and toilet with a black floor.

# %%
model = VisionEncoderDecoderModel.from_encoder_decoder_pretrained(
    encoder, decoder
)

model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.pad_token_id = tokenizer.pad_token_id
# Out:
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at sentence-transformers/all-MiniLM-L6-v2 and are newly initialized: ['encoder.layer.0.crossattention.output.LayerNorm.bias', 'encoder.layer.1.crossattention.output.LayerNorm.bias', 'encoder.layer.1.crossattention.output.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'encoder.layer.1.crossattention.output.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'encoder.layer.5.crossattention.output.LayerNorm.bias', 'encoder.layer.1.crossattention.self.key.weight', 'encoder.layer.5.crossattention.self.query.bias', 'encoder.layer.4.crossattention.self.value.weight', 'cls.predictions.bias', 'encoder.layer.3.crossattention.self.query.bias', 'encoder.layer.1.crossattention.self.key.bias', 'encoder.layer.0.crossattention.self.query.weight', 'encoder.layer.3.crossattention.output.dense.weight', 'encoder.layer.3.crossattention.output.dense.bias', 'encoder.layer.2.crossattention.self.query.weight', 'encoder.layer.0.crossattention.self.value.weight', 'encoder.layer.3.crossattention.output.LayerNorm.bias', 'encoder.layer.5.crossattention.self.key.weight', 'encoder.layer.5.crossattention.self.query.weight', 'encoder.layer.3.crossattention.self.value.bias', 'encoder.layer.4.crossattention.output.LayerNorm.weight', 'encoder.layer.3.crossattention.self.value.weight', 'encoder.layer.2.crossattention.self.value.bias', 'encoder.layer.3.crossattention.self.key.bias', 'encoder.layer.5.crossattention.output.LayerNorm.weight', 'encoder.layer.3.crossattention.self.query.weight', 'encoder.layer.0.crossattention.output.dense.weight', 'encoder.layer.4.crossattention.self.key.weight', 'encoder.layer.2.crossattention.output.dense.bias', 'encoder.layer.5.crossattention.self.value.weight', 'encoder.layer.4.crossattention.self.value.bias', 'encoder.layer.4.crossattention.output.dense.bias', 'encoder.layer.5.crossattention.output.dense.bias', 'encoder.layer.0.crossattention.self.query.bias', 'encoder.layer.2.crossattention.self.value.weight', 'encoder.layer.3.crossattention.self.key.weight', 'encoder.layer.1.crossattention.self.value.bias', 'encoder.layer.2.crossattention.output.LayerNorm.bias', 'encoder.layer.1.crossattention.self.query.weight', 'encoder.layer.2.crossattention.output.LayerNorm.weight', 'encoder.layer.2.crossattention.self.query.bias', 'encoder.layer.1.crossattention.self.value.weight', 'encoder.layer.5.crossattention.self.value.bias', 'encoder.layer.4.crossattention.self.query.weight', 'encoder.layer.2.crossattention.output.dense.weight', 'encoder.layer.4.crossattention.self.key.bias', 'encoder.layer.0.crossattention.output.LayerNorm.weight', 'encoder.layer.4.crossattention.self.query.bias', 'encoder.layer.0.crossattention.self.key.bias', 'cls.predictions.decoder.bias', 'encoder.layer.5.crossattention.output.dense.weight', 'encoder.layer.4.crossattention.output.LayerNorm.bias', 'encoder.layer.0.crossattention.self.value.bias', 'encoder.layer.2.crossattention.self.key.bias', 'encoder.layer.0.crossattention.self.key.weight', 'encoder.layer.1.crossattention.self.query.bias', 'encoder.layer.4.crossattention.output.dense.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'encoder.layer.0.crossattention.output.dense.bias', 'encoder.layer.5.crossattention.self.key.bias', 'encoder.layer.1.crossattention.output.dense.bias', 'encoder.layer.2.crossattention.self.key.weight', 'encoder.layer.3.crossattention.output.LayerNorm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    evaluation_strategy="steps",
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
    fp16=True, 
    output_dir="./",
    logging_steps=2,
    num_train_epochs=5,
    save_steps=100000,
    eval_steps=500,
    dataloader_num_workers=12,
    report_to='none'
)

# %%
def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions

    pred_str = processor.batch_decode(pred_ids, skip_special_tokens=True)
    labels_ids[labels_ids == -100] = processor.tokenizer.pad_token_id
    label_str = processor.batch_decode(labels_ids, skip_special_tokens=True)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)
    true_predictions = [f'{p} -> {l} ' for p, l in zip(pred_str, label_str) if p == l][:5]
    false_predictions = [f'{p} -> {l} ' for p, l in zip(pred_str, label_str) if p != l][:5]

    return {"wer": wer, "true_predictions": true_predictions, "false_predictions": false_predictions}

# %%
# instantiate trainer
trainer = Seq2SeqTrainer(
    model=model,
    tokenizer=processor.feature_extractor,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=default_data_collator
)
trainer.train()
# Out:
# /home/vladimir/.virtualenvs/ml/lib/python3.10/site-packages/transformers/models/trocr/processing_trocr.py:135: FutureWarning: `feature_extractor` is deprecated and will be removed in v5. Use `image_processor` instead.
#   warnings.warn(
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
#     <div>
#
#       <progress value='14560' max='14560' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14560/14560 2:19:44, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>True Predictions</th>
#       <th>False Predictions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.790300</td>
#       <td>2.703053</td>
#       <td>0.821191</td>
#       <td>['a man is playing tennis on a tennis court. -> a man is playing tennis on a tennis court. ', 'a man riding skis down a snow covered slope. -> a man riding skis down a snow covered slope. ', 'a man riding skis down a snow covered slope. -> a man riding skis down a snow covered slope. ', 'a man riding skis down a snow covered slope. -> a man riding skis down a snow covered slope. ', 'a man is playing tennis on a tennis court. -> a man is playing tennis on a tennis court. ']</td>
#       <td>['a cat is sitting on a table with a cat. -> two cats are eating food out of a plate ', 'a living room with a couch and a couch. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing in a field with a giraffe. -> a giraffe walking around in a zoo pin. ', 'a man standing in front of a building. -> a woman standing on a street corner near a traffic light. ', 'a bus parked in a city street. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.482700</td>
#       <td>2.464758</td>
#       <td>0.811381</td>
#       <td>['a man is playing tennis on a tennis court. -> a man is playing tennis on a tennis court. ', 'a young boy is standing in a bathroom. -> a young boy is standing in a bathroom. ', 'a laptop computer sitting on top of a bed. -> a laptop computer sitting on top of a bed. ', 'a group of people playing a game of frisbee. -> a group of people playing a game of frisbee. ', 'a laptop computer sitting on top of a table. -> a laptop computer sitting on top of a table. ']</td>
#       <td>['a cat is laying on a white chair. -> two cats are eating food out of a plate ', 'a living room with a couch and a couch. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing in a field with a giraffe. -> a giraffe walking around in a zoo pin. ', 'a man standing next to a fence with a sign on it. -> a woman standing on a street corner near a traffic light. ', 'a bus is parked on the street next to a bus. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.521200</td>
#       <td>2.346944</td>
#       <td>0.805218</td>
#       <td>['a large jetliner sitting on top of a runway. -> a large jetliner sitting on top of a runway. ', 'a man riding a snowboard down a snow covered slope. -> a man riding a snowboard down a snow covered slope. ', 'a man holding a tennis racquet on a tennis court. -> a man holding a tennis racquet on a tennis court. ', 'a man holding a tennis racket on a tennis court. -> a man holding a tennis racket on a tennis court. ', 'a laptop computer sitting on top of a bed. -> a laptop computer sitting on top of a bed. ']</td>
#       <td>['a cat is laying on a floor next to a bowl of food. -> two cats are eating food out of a plate ', 'a living room with a couch and a couch. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing next to a fence in a zoo. -> a giraffe walking around in a zoo pin. ', 'a man standing next to a sign on a street. -> a woman standing on a street corner near a traffic light. ', 'a bus is driving down the street next to a bus stop. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.427000</td>
#       <td>2.268615</td>
#       <td>0.810372</td>
#       <td>['a large jetliner sitting on top of a runway. -> a large jetliner sitting on top of a runway. ', 'a person walking on a beach with a surfboard. -> a person walking on a beach with a surfboard. ', 'a double decker bus driving down a street. -> a double decker bus driving down a street. ', 'a man and a woman playing a video game. -> a man and a woman playing a video game. ', 'a group of people sitting on a bench. -> a group of people sitting on a bench. ']</td>
#       <td>['a cat laying on a floor next to a cat. -> two cats are eating food out of a plate ', 'a living room with a couch and a couch. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing next to a fenced in enclosure. -> a giraffe walking around in a zoo pin. ', 'a man standing next to a street sign on a sidewalk. -> a woman standing on a street corner near a traffic light. ', 'a bus driving down a street with a bus parked on it. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.399500</td>
#       <td>2.210225</td>
#       <td>0.798157</td>
#       <td>['a man riding a surfboard on top of a wave. -> a man riding a surfboard on top of a wave. ', 'a man sitting at a table eating pizza. -> a man sitting at a table eating pizza. ', 'a laptop computer sitting on top of a bed. -> a laptop computer sitting on top of a bed. ', 'a person holding a remote control in front of a tv. -> a person holding a remote control in front of a tv. ', 'a couple of horses standing in a field. -> a couple of horses standing in a field. ']</td>
#       <td>['a cat is laying on a table with a cat on it. -> two cats are eating food out of a plate ', 'a living room with a couch, couch, couch, and a table. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing next to a fence in a zoo. -> a giraffe walking around in a zoo pin. ', 'a man and a woman walking down a street. -> a woman standing on a street corner near a traffic light. ', 'a bus is parked in a parking lot. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.200100</td>
#       <td>2.166849</td>
#       <td>0.790081</td>
#       <td>['a man riding a surfboard on top of a wave. -> a man riding a surfboard on top of a wave. ', 'a young boy is standing in a bathroom. -> a young boy is standing in a bathroom. ', 'a man sitting at a table eating pizza. -> a man sitting at a table eating pizza. ', 'a laptop computer sitting on top of a bed. -> a laptop computer sitting on top of a bed. ', 'a sandwich and a drink on a table. -> a sandwich and a drink on a table. ']</td>
#       <td>['a cat is laying on a table next to a cat. -> two cats are eating food out of a plate ', 'a living room with a couch and a couch. -> a living room with leather couch, settee and chair, rustic tables and a cowhide rug. ', 'a giraffe standing next to a fence in a zoo. -> a giraffe walking around in a zoo pin. ', 'a man and woman standing next to a street sign. -> a woman standing on a street corner near a traffic light. ', 'a bus is driving down the street next to a bus. -> a small car is driving along side a passenger bus ']</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.098600</td>
#       <td>2.130784</td>
#       <td>0.790633</td>
#       <td>['a train traveling down tracks next to a forest. -> a train traveling down tracks next to a forest. ', 'a man riding a wave on top of a surfboard. -> a man riding a wave on top of a surfboard. ', 'a man sitting at a table eating pizza. -> a man sitting at a table eating pizza. ', 'a man riding a wave on top of a surfboard. -> a man riding a wave on top of a surfboard. ', 'a laptop computer sitting on top of a bed. -> a laptop computer sitting on top of a bed. ']</td>
#       <td>['a cat and a cat are sitting on a table. -> two cats are eating food out of a plate ', 'a living room with a cou
# /home/vladimir/.virtualenvs/ml/lib/python3.10/site-packages/transformers/generation/utils.py:1421: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# /home/vladimir/.virtualenvs/ml/lib/python3.10/site-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# TrainOutput(global_step=14560, training_loss=2.10668328923511, metrics={'train_runtime': 8389.5367, 'train_samples_per_second': 222.123, 'train_steps_per_second': 1.735, 'total_flos': 7.101512109535334e+19, 'train_loss': 2.10668328923511, 'epoch': 5.0})

# %%
image = Image.open('train2014/COCO_train2014_000000000127.jpg').convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x481>

# %%
pixel_values = processor(image, return_tensors="pt").pixel_values

generated_ids = model.generate(pixel_values.to('cuda'))
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
generated_text
# Out:
# 'a plate with a cup of coffee and a cup of coffee.'
